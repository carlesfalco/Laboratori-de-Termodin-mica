# %%
from math import pi
from numpy import array, mean, std, sqrt, log, linspace, exp, polyfit, diag, loadtxt, concatenate, load, save
from scipy.stats import linregress
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.pylab as pl

# %%
p1 = load('or_1.npy')
p2 = load('or_2.npy')
p3 = load('or_3.npy')
p4 = load('or_4.npy')
p5 = load('or_5.npy')
p6 = load('or_6.npy')
p7 = load('or_7.npy')
p8 = load('or_8.npy')
p9 = load('or_9.npy')
p10 = load('or_10.npy')
p11 = load('or_11.npy')
p12 = load('or_12.npy')
p13 = load('or_13.npy')
p14 = load('or_14.npy')
rcParams.update({'font.size': 18})
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.figure(figsize = (10,5))

labels = ['0.1','0.5','0.75','1','1.5','2','3','4','5','10','20','40']
dspan = linspace(0,1,len(p1))
ps = array([p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p12, p13, p14])[:-1]
plt.ylabel('$T(x,t = 1$ h$)\;(^\circ$C)')
plt.xlabel('Dist\`ancia (m)')
colors = pl.cm.viridis(linspace(1,0,len(ps)))
for i in range(len(ps)):
    plt.plot(dspan,ps[i],label = labels[i],linewidth = 1.1, color = colors[i])
leg = plt.legend(ncol = 3,prop={'size': 15})

for line in leg.get_lines():
    line.set_linewidth(2.0)
    
plt.savefig('simu5.pdf',bbox_inches = 'tight')
plt.show()
