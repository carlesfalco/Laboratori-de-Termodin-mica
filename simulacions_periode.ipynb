# %%
from math import pi
from numpy import array, mean, std, sqrt, log, linspace, exp, polyfit, diag, loadtxt, concatenate, load, save
from scipy.stats import linregress
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.pylab as pl

# %%
rcParams.update({'font.size': 18})
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.figure(figsize = (10,5))

au1 = load('au_tau1.npy')
au2 = load('au_tau2.npy')
au3 = load('au_tau3.npy')
au4 = load('au_tau4.npy')
au5 = load('au_tau5.npy')

tspan = linspace(0,9000-1709,len(au1))


au = [au1,au3,au5]

colors = pl.cm.viridis(linspace(1,0,len(au)))
labels = ['200','700','3500']

for i in range(len(au)):
    plt.plot(tspan/60,au[i],linewidth = 1.1, color = colors[i],label = labels[i])
plt.ylabel('$T(x = $ 8 cm$,t)\;(^\circ$C)')
plt.xlabel('Temps (min)')

leg = plt.legend(prop={'size': 15}, bbox_to_anchor = [0.76,1.16], ncol = len(au))

for line in leg.get_lines():
    line.set_linewidth(2.0)
plt.savefig('simu_periodes.pdf',bbox_inches = 'tight')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:30: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:30: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
